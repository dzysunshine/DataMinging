# %% [markdown]
# # 1.首先要读取数据

# %%
import numpy
import pandas as pd

# %%
df = pd.read_csv('data.csv',encoding='gbk')
df.head()
# Out:
#    Unnamed: 0   custid                          trade_no bank_card_no  \
# 0           5  2791858  20180507115231274000000023057383          卡号1
# 1          10   534047  20180507121002192000000023073000          卡号1
# 2          12  2849787  20180507125159718000000023114911          卡号1
# 3          13  1809708  20180507121358683000000388283484          卡号1
# 4          14  2499829  20180507115448545000000388205844          卡号1
#
#    low_volume_percent  middle_volume_percent  \
# 0                0.01                   0.99
# 1                0.02                   0.94
# 2                0.04                   0.96
# 3                0.00                   0.96
# 4                0.01                   0.99
#
#    take_amount_in_later_12_month_highest  trans_amount_increase_rate_lately  \
# 0                                      0                               0.90
# 1                                   2000                               1.28
# ...

# %% [markdown]
# ## 查看每个特征缺失值的数目的总和

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                  0
# custid                                      0
# trade_no                                    0
# bank_card_no                                0
# low_volume_percent                          2
# middle_volume_percent                       2
# take_amount_in_later_12_month_highest       0
# trans_amount_increase_rate_lately           3
# trans_activity_month                        2
# trans_activity_day                          2
# transd_mcc                                  2
# trans_days_interval_filter                  8
# trans_days_interval                         2
# regional_mobility                           2
# student_feature                          2998
# repayment_capability                        0
# is_high_user                                0
# number_of_trans_from_2011                   2
# first_transaction_time                      2
# historical_trans_amount                     0
# ...

# %% [markdown]
# ## 可以发现，student_feature的缺失值最多

# %% [markdown]
# 删除id列

# %%
df.drop(["Unnamed: 0"],axis=1, inplace=True)
df.head()
# Out:
#     custid                          trade_no bank_card_no  low_volume_percent  \
# 0  2791858  20180507115231274000000023057383          卡号1                0.01
# 1   534047  20180507121002192000000023073000          卡号1                0.02
# 2  2849787  20180507125159718000000023114911          卡号1                0.04
# 3  1809708  20180507121358683000000388283484          卡号1                0.00
# 4  2499829  20180507115448545000000388205844          卡号1                0.01
#
#    middle_volume_percent  take_amount_in_later_12_month_highest  \
# 0                   0.99                                      0
# 1                   0.94                                   2000
# 2                   0.96                                      0
# 3                   0.96                                   2000
# 4                   0.99                                      0
#
#    trans_amount_increase_rate_lately  trans_activity_month  \
# ...

# %% [markdown]
# 查看数据集的数据类型

# %%
df.dtypes
# Out:
# custid                                     int64
# trade_no                                  object
# bank_card_no                              object
# low_volume_percent                       float64
# middle_volume_percent                    float64
# take_amount_in_later_12_month_highest      int64
# trans_amount_increase_rate_lately        float64
# trans_activity_month                     float64
# trans_activity_day                       float64
# transd_mcc                               float64
# trans_days_interval_filter               float64
# trans_days_interval                      float64
# regional_mobility                        float64
# student_feature                          float64
# repayment_capability                       int64
# is_high_user                               int64
# number_of_trans_from_2011                float64
# first_transaction_time                   float64
# historical_trans_amount                    int64
# ...

# %% [markdown]
# 查看数据集的基本信息：维度、列名称、数据格式、所占空间等

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4754 entries, 0 to 4753
# Data columns (total 89 columns):
# custid                                        4754 non-null int64
# trade_no                                      4754 non-null object
# bank_card_no                                  4754 non-null object
# low_volume_percent                            4752 non-null float64
# middle_volume_percent                         4752 non-null float64
# take_amount_in_later_12_month_highest         4754 non-null int64
# trans_amount_increase_rate_lately             4751 non-null float64
# trans_activity_month                          4752 non-null float64
# trans_activity_day                            4752 non-null float64
# transd_mcc                                    4752 non-null float64
# trans_days_interval_filter                    4746 non-null float64
# trans_days_interval                           4752 non-null float64
# ...

# %% [markdown]
# 可以看出非数值型的有7个，其他均为数值型，对不同类型数据进行不同的处理

# %%
obj_col=['trade_no',"bank_card_no",'reg_preference_for_trad', 'source',
                 'id_name', 'latest_query_time', 'loans_latest_time']
df_obj = df[obj_col]
df_num = df.drop(obj_col, axis=1)

# %%
df_obj.describe()
# Out:
#                                 trade_no bank_card_no reg_preference_for_trad  \
# count                               4754         4754                    4752
# unique                              4754            1                       5
# top     20180507122943882000000388345370          卡号1                    一线城市
# freq                                   1         4754                    3403
#
#        source id_name latest_query_time loans_latest_time
# count    4754    4478              4450              4457
# unique      1    4309               207               232
# top        xs      李明        2018-04-14        2018-05-03
# freq     4754       5               423               134

# %% [markdown]
# unique表示的是唯一值，可以看出，bank_card_no,source都只有1个，可将这两个特征删除，而id_name和trade_no均为编号，也可删除

# %%
df_obj.drop(['trade_no','bank_card_no','id_name','source'],axis=1,inplace=True)
# Out:
# D:\anoconda\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df_obj.describe()
# Out:
#        reg_preference_for_trad latest_query_time loans_latest_time
# count                     4752              4450              4457
# unique                       5               207               232
# top                       一线城市        2018-04-14        2018-05-03
# freq                      3403               423               134

# %%
df_num.describe()
# Out:
#              custid  low_volume_percent  middle_volume_percent  \
# count  4.754000e+03         4752.000000            4752.000000
# mean   1.690993e+06            0.021806               0.901294
# std    1.034235e+06            0.041527               0.144856
# min    1.140000e+02            0.000000               0.000000
# 25%    7.593358e+05            0.010000               0.880000
# 50%    1.634942e+06            0.010000               0.960000
# 75%    2.597905e+06            0.020000               0.990000
# max    4.004694e+06            1.000000               1.000000
#
#        take_amount_in_later_12_month_highest  \
# count                            4754.000000
# mean                             1940.197728
# std                              3923.971494
# min                                 0.000000
# 25%                                 0.000000
# 50%                               500.000000
# 75%                              2000.000000
# ...

# %%
df_num.drop(['custid', 'student_feature'],axis=1, inplace=True)

# %% [markdown]
# 缺失值可通过用均值填充、众数填充或删除的方法

# %% [markdown]
# 对于数值型数据，采用均值填充

# %%
from sklearn.preprocessing import Imputer

imputer = Imputer(strategy='mean')
num = imputer.fit_transform(df_num)
df_num = pd.DataFrame(num, columns=df_num.columns)

# %% [markdown]
# 对于非数值型数据，采用前值填充

# %%
df_obj.ffill(inplace=True)
# Out:
# D:\anoconda\lib\site-packages\pandas\core\frame.py:3787: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %% [markdown]
# 非数值型数据的类型转换:
#
# 0-1转换 标签二值化LabelBinarizer

# %%
df_obj.describe()
# Out:
#        reg_preference_for_trad latest_query_time loans_latest_time
# count                     4754              4754              4754
# unique                       5               207               232
# top                       一线城市        2018-04-14        2018-05-03
# freq                      3404               447               145

# %%
from sklearn.preprocessing import LabelBinarizer

#help(preprocessing.LabelBinarizer)

encoder = LabelBinarizer()
reg_preference_1hot = encoder.fit_transform(df_obj['reg_preference_for_trad'])
df_obj.drop(['reg_preference_for_trad'], axis=1, inplace=True)

#df_obj一定要在处理这步前填充缺失值，不然会因为无法处理NA而报错

reg_preference_df = pd.DataFrame(reg_preference_1hot, columns=encoder.classes_)
df_obj = pd.concat([df_obj, reg_preference_df], axis=1)
# Out:
# D:\anoconda\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df_obj.describe()
# Out:
#               一线城市         三线城市         二线城市         其他城市           境外  \
# count  4754.000000  4754.000000  4754.000000  4754.000000  4754.000000
# mean      0.716029     0.224022     0.027556     0.000841     0.031552
# std       0.450971     0.416980     0.163713     0.028998     0.174823
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       1.000000     0.000000     0.000000     0.000000     0.000000
# 75%       1.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#        latest_query_time_month  latest_query_time_weekday  \
# count              4754.000000                4754.000000
# mean                  4.289230                   3.311527
# std                   1.379977                   1.954760
# min                   1.000000                   0.000000
# ...

# %% [markdown]
# 数据切分

# %%
from sklearn.model_selection import train_test_split
train , test = train_test_split(data_2, test_size = 0.3)
